# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
pd.set_option("display.max_columns", None)

# %%
df_originnal = pd.read_csv("data/01 raw/ELSA/Encuesta al personal 2023 español .csv")
df_originnal.head()
# Out:
#    measurement_process_id      ip_001         ip_002 ip_003      ip_004  \
# 0                      22   Femenino.  30 - 49 años.    No.  Mestizo/a.
# 1                      22  Masculino.  30 - 49 años.    No.  Mestizo/a.
# 2                      12   Femenino.  30 - 49 años.    No.  Mestizo/a.
# 3                      22   Femenino.  30 - 49 años.    No.  Mestizo/a.
# 4                      22   Femenino.  50 - 59 años.    No.  Mestizo/a.
#
#                                               il_001    il_002  \
# 0  Contrato o vínculo laboral a plazo indetermina...    Diurno
# 1  Contrato o vínculo laboral a plazo fijo (tiene...    Diurno
# 2  Contrato o vínculo laboral a plazo indetermina...  Rotativo
# 3  Contrato o vínculo laboral a plazo fijo (tiene...    Diurno
# 4  Contrato o vínculo laboral a plazo indetermina...    Diurno
#
#                    il_003                                             il_004  \
# ...
